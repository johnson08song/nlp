# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.3.2-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.10.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.28.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.4.6)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.3.2-py3-none-any.whl (485 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.4/485.4 kB 15.0 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 6.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 10.6 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 12.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, datasets
# Successfully installed datasets-3.3.2 dill-0.3.8 multiprocess-0.70.16 xxhash-3.5.0

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments, EarlyStoppingCallback, AutoModel
from datasets import Dataset
import re
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import torch
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, confusion_matrix, roc_curve, auc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/NLP電商專案/資料爬蟲/final227.csv')

# %%
label_encoder = LabelEncoder()
df['Rating'] = label_encoder.fit_transform(df['Rating'])

# 先把 20% 的數據作為測試集
train_val_texts, test_texts, train_val_labels, test_labels = train_test_split(
    df['Comment'].tolist(),
    df['Rating'].tolist(),
    test_size=0.2,  # 20% 測試集
    random_state=42,
    stratify=df['Rating'].tolist()  # 確保測試集和訓練集的比例相同
)

# 再從剩下的 80% 裡取 20% 當驗證集（相當於原始數據的 16%）
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_val_texts,
    train_val_labels,
    test_size=0.2,  # 20% of 80% = 16%
    random_state=42,
    stratify=train_val_labels  # 確保驗證集和訓練集的比例相同
)

tokenizer = AutoTokenizer.from_pretrained('hfl/chinese-macbert-base')
def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)

# Convert train and validation data to Hugging Face Dataset format
train_dataset = Dataset.from_pandas(pd.DataFrame({'text': train_texts, 'label': train_labels}))
val_dataset = Dataset.from_pandas(pd.DataFrame({'text': val_texts, 'label': val_labels}))
test_dataset = Dataset.from_pandas(pd.DataFrame({'text': test_texts, 'label': test_labels}))

# Tokenize the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the format for PyTorch (input_ids, attention_mask, and label)
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Load pre-trained BERT model for sequence classification
model = AutoModelForSequenceClassification.from_pretrained('hfl/chinese-macbert-base', num_labels=len(label_encoder.classes_))

training_args = TrainingArguments(
    output_dir='./results',           # Output directory for saving model
    num_train_epochs=10,             # Number of training epochs
    per_device_train_batch_size=32,       # Batch size for training
    per_device_eval_batch_size=64,       # Batch size for evaluation
    load_best_model_at_end=True,
    warmup_steps=300,               # Number of warmup steps
    weight_decay=0.01,              # Weight decay to avoid overfitting
    logging_dir='./logs',            # Directory for storing logs
    logging_steps=10,               # How often to log the results
    evaluation_strategy='epoch',         # Evaluate at the end of each epoch
    save_strategy='epoch',            # Save model after each epoch
    report_to='none',                  # Disable reporting to any logging service
    learning_rate=5e-5,
    lr_scheduler_type='cosine'
)

# Function to compute metrics (accuracy, precision, recall, f1)
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)  # Get predicted classes
    acc = accuracy_score(labels, preds)  # Accuracy
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')  # Precision, recall, F1 score
    cm = confusion_matrix(labels, preds)  # Confusion matrix

    # Convert confusion matrix (which is a numpy ndarray) to a list to avoid serialization error
    cm = cm.tolist()

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

    return {
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': cm  # Return as a list
    }

trainer = Trainer(
    model=model,                      # The model to be trained
    args=training_args,                # Training arguments
    train_dataset=train_dataset,       # Training dataset
    eval_dataset=val_dataset,          # Validation dataset
    compute_metrics=compute_metrics,
    callbacks=[EarlyStoppingCallback(early_stopping_patience=2)]
)

trainer.train()
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/659 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/110k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/269k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Map:   0%|          | 0/21120 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5280 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6600 [00:00<?, ? examples/s]
# pytorch_model.bin:   0%|          | 0.00/412M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at hfl/chinese-macbert-base and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='1980' max='6600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1980/6600 22:53 < 53:28, 1.44 it/s, Epoch 3/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Confusion Matrix</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.255300</td>
#       <td>0.240645</td>
#       <td>0.907197</td>
#       <td>0.908015</td>
#       <td>0.907197</td>
#       <td>0.907458</td>
#       <td>[[1544, 14, 202], [16, 1684, 60], [159, 39, 1562]]</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.266500</td>
#       <td>0.243743</td>
#       <td>0.910985</td>
#       <td>0.911929</td>
#       <td>0.910985</td>
#       <td>0.911330</td>
#       <td>[[1598, 11, 151], [15, 1672, 73], [195, 25, 1540]]</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.097700</td>
#       <td>0.327302</td>
#       <td>0.917992</td>
#       <td>0.917735</td>
#       <td>0.917992</td>
#       <td>0.917778</td>
#       <td>[[1561, 14, 185], [11, 1724, 25], [142, 56, 1562]]</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1980, training_loss=0.22357142620315457, metrics={'train_runtime': 1375.6211, 'train_samples_per_second': 153.531, 'train_steps_per_second': 4.798, 'total_flos': 4167716536811520.0, 'train_loss': 0.22357142620315457, 'epoch': 3.0})

# %%
# 取得模型預測
predictions = trainer.predict(test_dataset)

# 轉換預測結果
predicted_labels = predictions.predictions.argmax(axis=-1)

# 轉回原始標籤名稱
decoded_predictions = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(test_labels)

# 印出前 10 筆測試結果，包含評論內容
for i in range(10):
    print(f"評論: {test_texts[i]}")
    print(f"真實標籤: {decoded_true_labels[i]}  |  預測標籤: {decoded_predictions[i]}")
    print("-" * 50)  # 分隔線，讓輸出更清楚
# Out:
# 評論: 雖說是精裝版收到的時候封面正反面都是泥不知道怎麼弄的很髒
# 真實標籤: neutral  |  預測標籤: bad
# --------------------------------------------------
# 評論: 常買的零食之有特價就買大品牌有信心
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 送貨速度超快產品也很好用謝謝
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 不要買啊這書上面全是錯的完全是了賺考研學生的錢粗製濫造啊不要上當啊還沒網上下載的全
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 賣家很瞎耶完全沒用箱子包裝我訂樣東西全給我裸包是要叫我怎麼拿
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 好用商品希望常常有特惠價
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 書的包裝不好紙張也很差感覺像是盜版
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 買來彈吉他用的聲音發悶發緊不如另一隻
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 鍵一開始按有點不順後來就好了
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 多次回購用很兇非常好用
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------

# %%
test_results = trainer.evaluate(test_dataset)

print("Test Set Results:")
print(test_results)
# Out:
#     <div>
#
#       <progress value='104' max='104' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [104/104 00:40]
#     </div>
# Test Set Results:
# {'eval_loss': 0.23051738739013672, 'eval_accuracy': 0.906969696969697, 'eval_precision': 0.9073692462851728, 'eval_recall': 0.906969696969697, 'eval_f1': 0.9071489915311698, 'eval_confusion_matrix': [[1959, 13, 228], [19, 2105, 76], [221, 57, 1922]], 'eval_runtime': 40.8693, 'eval_samples_per_second': 161.49, 'eval_steps_per_second': 2.545, 'epoch': 3.0}

# %%
# 取得模型預測
predictions = trainer.predict(test_dataset)

# 轉換預測結果
predicted_labels = predictions.predictions.argmax(axis=-1)

# 轉回原始標籤名稱
decoded_predictions = label_encoder.inverse_transform(predicted_labels)
decoded_true_labels = label_encoder.inverse_transform(test_labels)

# 印出前 10 筆測試結果，包含評論內容
for i in range(100):
    print(f"評論: {test_texts[i]}")
    print(f"真實標籤: {decoded_true_labels[i]}  |  預測標籤: {decoded_predictions[i]}")
    print("-" * 50)  # 分隔線，讓輸出更清楚
# Out:
# 評論: 雖說是精裝版收到的時候封面正反面都是泥不知道怎麼弄的很髒
# 真實標籤: neutral  |  預測標籤: bad
# --------------------------------------------------
# 評論: 常買的零食之有特價就買大品牌有信心
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 送貨速度超快產品也很好用謝謝
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 不要買啊這書上面全是錯的完全是了賺考研學生的錢粗製濫造啊不要上當啊還沒網上下載的全
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 賣家很瞎耶完全沒用箱子包裝我訂樣東西全給我裸包是要叫我怎麼拿
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 好用商品希望常常有特惠價
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 書的包裝不好紙張也很差感覺像是盜版
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 買來彈吉他用的聲音發悶發緊不如另一隻
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 鍵一開始按有點不順後來就好了
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 多次回購用很兇非常好用
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 手套的材質過於厚重戴著會讓手部感到很不靈活影響日常活動
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 出貨超快速品質沒問題讚讚
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 設計不合理無法使用讓我很失望
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 質量太差了揹帶脫絲這樣的問題也會發貨說明這家商家太不負責任了
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 出貨速度快價格優惠有需要會再購買
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 這款茶的口感非常不順口喝起來很澀完全無法享受茶的原味
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 買回來剛洗了次然後中間圖案的色就掉完了掉色掉的厲害穿出去跟舊的差不多望想買的人三思而且那麼貴還不如在加點錢到實體店買還有安全保障能夠保證是正品
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 用了一兩個月後開始出現死機現象非常糟糕
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 上週剛拿到書感覺不論從紙張還是書的內容來說整體還是不錯的就是覺得案例還是少了點
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 品質不行螺絲孔根本就爛掉了一鎖下去直接滑牙
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 快又好定期回購的好物
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 時間太短了
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 這款跑步鞋不夠透氣穿久了腳會非常悶熱
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 是本好書內容可以可是這本週年紀念版的紙質好差黃黃的暗暗的唉很失望
# 真實標籤: neutral  |  預測標籤: bad
# --------------------------------------------------
# 評論: 肉質鮮美真材實料的物流服務很貼心已是回購
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 出貨速度很快很棒但電量顯示面板有多處細微刮痕
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 使用好幾年的粉底液一再回購上面買非常划算
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 商品很差勁起球不說還縮水
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 書的內容還行這個版本不是很好紙張不好沒有感覺文章就是教導人做好員工積極主動樂觀向上內容還是可以的
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 類比搖桿會卡住回不來方向鍵需大力按壓才有反應
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 手機的顯示效果很差根本無法使用
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 這是第二次在卓越網買書這次的書質量不好挺糟糕的因我是買來送人的所以我收到書的時候沒有去翻閱去仔細看然後就直接拿去送給朋友了朋友看後就很鬱悶告訴我書的質量糟糕好吧我只能說買書也是要看人品的人品不好的確是更容易買到質量不好的書可是卓越沒有辦法讓人品不好的人也買到好書
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 這批柿子熟度剛好但部分果肉有點澀
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 還沒使用效期都有到年
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 好吃
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 發錯貨有一個還是壞的還得讓我重新買一個退還很麻煩懶得退了
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 料理機的刀片鋒利能夠快速處理食材但機身較重對於一些較小的家庭來說可能不太實用
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 書是破的其他還好其實也是你們跟錢穆給沾光了
# 真實標籤: bad  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 出貨速度與預定一致特價訂購實惠又美味
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 非常好的服務
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 好吃家裡必備零食特價立馬下單
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 滑雪登山杖的穩定度一般握柄防滑效果還行
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 這一批買到特價中的特價很划算
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 弄在臉上洗不掉啊好差勒
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 圖片是草綠的實物來了就是白色的陶瓷杯子我勒個去啊忽悠呢就加個綠色的套套就成草綠了
# 真實標籤: bad  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 賣家出貨速度快且商品無瑕疵詢問時也很快的回答謝謝有機會會再回購的
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 送了一週都沒送到
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 桌板側邊不知是物流撞到還是出廠即有瑕疵如照片所示有一個破損的角角組裝過程需要稍微思考但能順利完成物流服務很好非常感謝
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 有特價又好吃每年都會買
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 賣的有點貴
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 我已經有兩次收到這樣的書了總是有脫頁或者某頁破損
# 真實標籤: bad  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 卜蜂雞胸肉是家中平日必備食材趁特價補貨
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 這台掃地機器人吸力差地板上的灰塵無法清潔乾
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 比市價優惠且有贈品又宅配至府
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 口罩有點鬆沒有很服貼
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 好吃不用多說特價時可以囤貨
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 總體而言還是不錯部分作品有些色差
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 買給幼稚園大班的小孩使用很輕量目前使用上都很
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 虎牌買送獨家彈蓋雙層不鏽鋼保冰保溫瓶輕量保溫杯品質好速度快
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 霓淨思淡斑精華液價格划算好用
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 談不上喜歡不喜歡
# 真實標籤: neutral  |  預測標籤: bad
# --------------------------------------------------
# 評論: 冰非常好吃也是用便宜的價格買下來
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 對於看過他的第一本書獨步天下的人來說這本遠遠沒有那本書帶來的震撼
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 葡萄籽萃取物的抗氧化作用值得注意對肌膚有一定的保護效果長期使用後皮膚顯得更加光滑但效果較慢需持續服用
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 水鍋的底部容易變形使用幾次後就發現有凹陷質量非常差
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 少少單片包裝很符合人開伙的需求好吃會再回購
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 這個遊戲機的配置太低玩一些較新的遊戲會卡頓
# 真實標籤: bad  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 眼線液筆筆頭偏軟新手可能不好掌握
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 該品自動對焦比較慢自動快門慢對焦成功或照片更清晰清晰
# 真實標籤: neutral  |  預測標籤: good
# --------------------------------------------------
# 評論: 背包的內部空間有限雖然標榜大容量但實際上並不夠用
# 真實標籤: bad  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 拿到書的時候封皮就是被撕爛的因急用懶得換了在亞馬遜購物最糟糕的一次體驗
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 騙錢的爛書這個出版社出了不少且都超貴想錢想瘋了喜劇難寫一位好萊塢編劇的真實告白講解了該如何進行喜劇大片劇本創作的一些技法全書共分三大部分章第一部分第章如何拼盡老命或者喜劇大學英雄聯盟第章喜劇點子亦稱不恰當的重要性布魯斯兄弟不是學習的榜樣第二部分第章喜劇角色亦稱一個傻蛋的旅程或我認識那樣的人第章滑稽和溫情亦稱青少年流氓集團狼戰術第三部分第章第章介紹了喜劇的個序列第章對劇本寫作進行了總結喜劇難寫一位好萊塢編劇的真實告白講解了該如何進行喜劇大片劇本創作的一些技法全書共分三大部分章第一部分第章如何拼盡老命或者喜劇大學英雄聯盟第章喜劇點子亦稱不恰當的重要性布魯斯兄弟不是學習的榜樣第二部分第章喜劇角色亦稱一個傻蛋的旅程或我認識那樣的人第章滑稽和溫情亦稱青少年流氓集團狼戰術第三部分第章第章介紹了喜劇的個序列第章對劇本寫作進行了總結
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 隨書贈閱的書還可以看看
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 第一次購買看評論應該不錯但昨天收到發現大小差很多普遍為小片不到公克希望不要欺騙會員購買時上面寫公克不在乎那一兩口但誠信很重要
# 真實標籤: good  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 出貨速度很快值很高
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 送來還是冷凍狀態好吃的話再來添購
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 螢幕顯示效果差顏色失真無法正常工作
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 這本字典性價比高並且版本較新很有用還不錯
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 爛的跟他媽狗屎一樣買來隔天就出現超嚴重的自動飄移情況
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 用不上雖說東西不錯
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 這個行充一直充不了電不管充多久就是只有一個燈詢問賣家一直沒有回覆目前無法使用
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 覺得外型很美容量大很實用
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 商品符合預期值不錯希望常有優惠活動
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 第一次在購買還有贈品馬克杯
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 沒有預期中持久早早就脫妝了
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 因附近超商沒在賣了就選擇的網購之前買過脹袋的丟了兩包這回沒脹袋但也不是真空狀態不知道這個是否是正常狀況貌似在超商買的包裝嚴實點
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 玩偶的尺寸比想像中的小完全不符合描述實際感覺非常失望
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 貌視有點像盜版額比之前買的那本中級口譯教程質量差很多但用起來也還行
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 煲啦幾天的耳機哼失望高中低頻亂成一窩粥沒有一點點聲場可言明顯趕差幾條街還接棒可笑的是外包裝上居然貼有兩個不一樣的防串號失敗
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 這種忽悠人的書真他媽沒意思不就看吳永志的書賣的好點全部換成這種標題和這個圖案的封面就是李鬼吳永志的書都不認可這更是個垃圾什麼玩意
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 餐紙巾的大小合適但厚度再加強一點會更好
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 書籍外盒有裂痕書籍有一本帶毛邊照片坑爹呢就是一張明信片然後用金色字體印上去的簽名書中連幅地圖都沒有這出版社賺錢賺瘋了要不是你出冰與火你其他出的書絕對不買
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 送來的時候盒子上被壓了一個坑卓越的包裝越來越差了外包裝什麼都沒有填充打開一看硬盤癟了一塊幸好插在電腦上還能用懶得換了就這樣把
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------
# 評論: 買了其他家一樣的東西這抱枕棉花明顯少了很多除了這個以外品質還不錯
# 真實標籤: neutral  |  預測標籤: good
# --------------------------------------------------
# 評論: 出貨速度快但是產品聲音很大聲跟電風扇聲音差不多大還有使用空間會悶濕是正常這幾天使用下來效果感覺沒有想像中的好
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 味道就是最普通的餅乾但也正因如此所以比較木有那麼多添加劑
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 出貨速度不錯商品收到的時候沒有退冰物流服務很好會持續回購
# 真實標籤: good  |  預測標籤: good
# --------------------------------------------------
# 評論: 不是非常喜歡這個故事幾米的作品中最愛每天心中開出一朵花
# 真實標籤: neutral  |  預測標籤: neutral
# --------------------------------------------------
# 評論: 幫朋友買的到現在還沒講哪裏用不舒服
# 真實標籤: neutral  |  預測標籤: bad
# --------------------------------------------------
# 評論: 很鬱悶手機右下角的返回鍵不怎麼靈有時直接按不了
# 真實標籤: bad  |  預測標籤: bad
# --------------------------------------------------

# %%
# Save the model and tokenizer
model.save_pretrained('./results')  # Save the model in the 'results' folder
tokenizer.save_pretrained('./results')  # Save the tokenizer in the 'results' folder
# Out:
# ('./results/tokenizer_config.json',
#  './results/special_tokens_map.json',
#  './results/vocab.txt',
#  './results/added_tokens.json',
#  './results/tokenizer.json')

# %%
label_encoder = LabelEncoder()
df['Rating'] = label_encoder.fit_transform(df['Rating'])
num_classes = len(label_encoder.classes_)

# 先把 20% 的數據作為測試集
train_val_texts, test_texts, train_val_labels, test_labels = train_test_split(
    df['Comment'].tolist(),
    df['Rating'].tolist(),
    test_size=0.2,  # 20% 測試集
    random_state=42,
    stratify=df['Rating'].tolist()  # 保持訓練集和測試集的類別比例
)

# 再從剩下的 80% 裡取 20% 當驗證集（相當於原始數據的 16%）
train_texts, val_texts, train_labels, val_labels = train_test_split(
    train_val_texts,
    train_val_labels,
    test_size=0.2,  # 20% of 80% = 16%
    random_state=42,
    stratify=train_val_labels  # 保持訓練集和驗證集的類別比例
)

tokenizer = AutoTokenizer.from_pretrained('bert-base-chinese')
def tokenize_function(examples):
    return tokenizer(examples['text'], padding='max_length', truncation=True, max_length=128)

# Convert train and validation data to Hugging Face Dataset format
train_dataset = Dataset.from_pandas(pd.DataFrame({'text': train_texts, 'label': train_labels}))
val_dataset = Dataset.from_pandas(pd.DataFrame({'text': val_texts, 'label': val_labels}))
test_dataset = Dataset.from_pandas(pd.DataFrame({'text': test_texts, 'label': test_labels}))

# Tokenize the datasets
train_dataset = train_dataset.map(tokenize_function, batched=True)
val_dataset = val_dataset.map(tokenize_function, batched=True)
test_dataset = test_dataset.map(tokenize_function, batched=True)

# Set the format for PyTorch (input_ids, attention_mask, and label)
train_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
val_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])
test_dataset.set_format(type='torch', columns=['input_ids', 'attention_mask', 'label'])

# Load pre-trained BERT model for sequence classification
model = AutoModelForSequenceClassification.from_pretrained('bert-base-chinese', num_labels=num_classes)

training_args = TrainingArguments(
    output_dir='./results',           # Output directory for saving model
    num_train_epochs=10,              # Number of training epochs
    per_device_train_batch_size=32,   # Batch size for training
    per_device_eval_batch_size=64,    # Batch size for evaluation
    load_best_model_at_end=True,
    warmup_steps=300,                 # Number of warmup steps
    weight_decay=0.01,                # Weight decay to avoid overfitting
    logging_dir='./logs',             # Directory for storing logs
    logging_steps=10,                 # How often to log the results
    evaluation_strategy='epoch',      # Evaluate at the end of each epoch
    save_strategy='epoch',            # Save model after each epoch
    report_to='none',                 # Disable reporting to any logging service
    learning_rate=5e-5,
    lr_scheduler_type='cosine'
)

# Function to compute metrics (accuracy, precision, recall, f1, AUC, ROC)
def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)  # Get predicted classes
    probs = torch.nn.functional.softmax(torch.tensor(pred.predictions), dim=-1).numpy() # Get probabilities

    acc = accuracy_score(labels, preds)  # Accuracy
    precision, recall, f1, _ = precision_recall_fscore_support(labels, preds, average='weighted')  # Precision, recall, F1 score
    cm = confusion_matrix(labels, preds)  # Confusion matrix

    # Convert confusion matrix (which is a numpy ndarray) to a list to avoid serialization error
    cm = cm.tolist()

    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

    # Compute ROC and AUC for each class (one-vs-rest)
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    for i in range(num_classes):
        y_true_binary = (labels == i).astype(int)
        y_score = probs[:, i]
        fpr[i], tpr[i], _ = roc_curve(y_true_binary, y_score)
        roc_auc[i] = auc(fpr[i], tpr[i])

    # Plot ROC curves
    plt.figure(figsize=(8, 6))
    for i in range(num_classes):
        plt.plot(fpr[i], tpr[i], label=f'ROC curve (class {label_encoder.classes_[i]}, AUC = {roc_auc[i]:.2f})')
    plt.plot([0, 1], [0, 1], 'k--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves')
    plt.legend(loc='lower right')
    plt.show()

    return {
        'accuracy': acc,
        'precision': precision,
        'recall': recall,
        'f1': f1,
        'confusion_matrix': cm,  # Return as a list
        'auc': roc_auc #Return auc dict
    }

trainer = Trainer(
    model=model,                       # The model to be trained
    args=training_args,                # Training arguments
    train_dataset=train_dataset,       # Training dataset
    eval_dataset=val_dataset,          # Validation dataset
    compute_metrics=compute_metrics
)

trainer.train()
# Out:
# Map:   0%|          | 0/21120 [00:00<?, ? examples/s]
# Map:   0%|          | 0/5280 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6600 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-chinese and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.11/dist-packages/transformers/training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
#     <div>
#
#       <progress value='6600' max='6600' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [6600/6600 1:13:26, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1</th>
#       <th>Confusion Matrix</th>
#       <th>Auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.300300</td>
#       <td>0.242283</td>
#       <td>0.901705</td>
#       <td>0.903886</td>
#       <td>0.901705</td>
#       <td>0.902116</td>
#       <td>[[1619, 9, 132], [24, 1656, 80], [256, 18, 1486]]</td>
#       <td>{0: 0.9782429945764463, 1: 0.9969869415030992, 2: 0.9698300297004132}</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.264700</td>
#       <td>0.265933</td>
#       <td>0.909659</td>
#       <td>0.911386</td>
#       <td>0.909659</td>
#       <td>0.910245</td>
#       <td>[[1573, 7, 180], [8, 1659, 93], [159, 30, 1571]]</td>
#       <td>{0: 0.9804342071280993, 1: 0.995807076446281, 2: 0.9720735408057851}</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.141000</td>
#       <td>0.244015</td>
#       <td>0.923485</td>
#       <td>0.923019</td>
#       <td>0.923485</td>
#       <td>0.923170</td>
#       <td>[[1591, 21, 148], [5, 1729, 26], [148, 56, 1556]]</td>
#       <td>{0: 0.9822804752066115, 1: 0.99831490508781, 2: 0.9775497159090909}</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.069100</td>
#       <td>0.393236</td>
#       <td>0.918371</td>
#       <td>0.919500</td>
#       <td>0.918371</td>
#       <td>0.918309</td>
#       <td>[[1647, 10, 103], [16, 1695, 49], [222, 31, 1507]]</td>
#       <td>{0: 0.9815134297520661, 1: 0.997261912448347, 2: 0.9712279668130166}</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.041300</td>
#       <td>0.468634</td>
#       <td>0.920455</td>
#       <td>0.920068</td>
#       <td>0.920455</td>
#       <td>0.920099</td>
#       <td>[[1600, 20, 140], [13, 1726, 21], [170, 56, 1534]]</td>
#       <td>{0: 0.9811988313533058, 1: 0.997477643982438, 2: 0.9768288352272728}</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.040000</td>
#       <td>0.508355</td>
#       <td>0.920076</td>
#       <td>0.920375</td>
#       <td>0.920076</td>
#       <td>0.920072</td>
#       <td>[[1562, 12, 186], [9, 1712, 39], [128, 48, 1584]]</td>
#       <td>{0: 0.9818689469266529, 1: 0.9980107986828511, 2: 0.9765648405216941}</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.015600</td>
#       <td>0.567206</td>
#       <td>0.922159</td>
#       <td>0.921943</td>
#       <td>0.922159</td>
#       <td>0.921965</td>
#       <td>[[1606, 15, 139], [10, 1720, 30], [173, 44, 1543]]</td>
#       <td>{0: 0.9829439727530992, 1: 0.9979054752066115, 2: 0.9782796358471073}</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.000100</td>
#       <td>0.638642</td>
#       <td>0.921212</td>
#       <td>0.921853</td>
#       <td>0.921212</td>
#       <td>0.921457</td>
#       <td>[[1583, 9, 168], [10, 1697, 53], [150, 26, 1584]]</td>
#       <td>{0: 0.98216361053719, 1: 0.9972496448863637, 2: 0.9776849819214876}</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.000000</td>
#       <td>0.636239</td>
#       <td>0.922159</td>
#       <td>0.922478</td>
#       <td>0.922159</td>
#       <td>0.922299</td>
#       <td>[[1590, 10, 160], [11, 1703, 46], [154, 30, 1576]]</td>
#       <td>{0: 0.9827871577995869, 1: 0.9975328480113634, 2: 0.9777904668130164}</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.000000</td>
#       <td>0.636150</td>
#       <td>0.922538</td>
#       <td>0.922899</td>
#       <td>0.922538</td>
#       <td>0.922679</td>
#       <td>[[1585, 11, 164], [9, 1704, 47], [148, 30, 1582]]</td>
#       <td>{0: 0.9829228273502068, 1: 0.9975468104338842, 2: 0.9779395338326446}</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=6600, training_loss=0.07880311856089534, metrics={'train_runtime': 4406.909, 'train_samples_per_second': 47.925, 'train_steps_per_second': 1.498, 'total_flos': 1.38923884560384e+16, 'train_loss': 0.07880311856089534, 'epoch': 10.0})
